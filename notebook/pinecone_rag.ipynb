# %% [markdown]
# ### RAG using Pinecone vectorDB

# %%
# Document Loading: PyPDFDirectoryLoader
# Document Splitting and Chunking: RecursiveCharacterTextSplitter
# VectorDB: Pinecone (raturihimanshu077@gmail.com)
# Embedding Model(Hugging Face): sentence-transformers/all-MiniLM-L12-v2
# LLM Model(Groq): llama-3.1-8b-instant

# %%
from dotenv import load_dotenv
from langchain_community.document_loaders import PyPDFDirectoryLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from pinecone.grpc import PineconeGRPC as Pinecone
from sentence_transformers import SentenceTransformer
load_dotenv()
# Out:
# True

# %%
# Reading pdf document
def read_doc(directory):
    file_loader = PyPDFDirectoryLoader(directory)
    document = file_loader.load()
    return document

# %%
# Document splitting and chunking
def chunk_data(document , chunk_size=1000,chunk_overlap=200):
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size , chunk_overlap=chunk_overlap)
    chunks = text_splitter.split_documents(document)
    return chunks

# %%
# Embedding using "sentence-transformers/all-MiniLM-L12-v2" : It maps sentences & paragraphs to a 384 dimensional dense vector space
def embedding_chunks(chunks):
    model = SentenceTransformer('sentence-transformers/all-MiniLM-L12-v2')
    text = [doc.page_content for doc in chunks]
    embeddings = model.encode(text)
    return embeddings

# %%
# Pinecone initialization
import os
pinecone_api_key = os.getenv("PINECONE_API_KEY")
pinecone_env = os.getenv("PINECONE_ENVIRONMENT")
pc = Pinecone(api_key=pinecone_api_key)
index_name = "test-rag"

# %%
documents = read_doc("../data/research_data/")
len(documents)
# Out:
# 459

# %%
chunks = chunk_data(documents)
print(len(chunks))
# Out:
# 1258

# %%
embeddings = embedding_chunks(chunks)
print(len(embeddings))
# Out:
# 1258

# %%
for doc in documents:
    print(doc.metadata)
# Out:
# {'producer': 'GPL Ghostscript 9.05', 'creator': '', 'creationdate': '2015-01-18T06:20:31-08:00', 'moddate': '2015-01-18T06:20:31-08:00', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\A_New_Generation_of_the_IMAGIC_Image_Pro.pdf', 'total_pages': 8, 'page': 0, 'page_label': '1'}
# {'producer': 'GPL Ghostscript 9.05', 'creator': '', 'creationdate': '2015-01-18T06:20:31-08:00', 'moddate': '2015-01-18T06:20:31-08:00', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\A_New_Generation_of_the_IMAGIC_Image_Pro.pdf', 'total_pages': 8, 'page': 1, 'page_label': '2'}
# {'producer': 'GPL Ghostscript 9.05', 'creator': '', 'creationdate': '2015-01-18T06:20:31-08:00', 'moddate': '2015-01-18T06:20:31-08:00', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\A_New_Generation_of_the_IMAGIC_Image_Pro.pdf', 'total_pages': 8, 'page': 2, 'page_label': '3'}
# {'producer': 'GPL Ghostscript 9.05', 'creator': '', 'creationdate': '2015-01-18T06:20:31-08:00', 'moddate': '2015-01-18T06:20:31-08:00', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\A_New_Generation_of_the_IMAGIC_Image_Pro.pdf', 'total_pages': 8, 'page': 3, 'page_label': '4'}
# {'producer': 'GPL Ghostscript 9.05', 'creator': '', 'creationdate': '2015-01-18T06:20:31-08:00', 'moddate': '2015-01-18T06:20:31-08:00', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\A_New_Generation_of_the_IMAGIC_Image_Pro.pdf', 'total_pages': 8, 'page': 4, 'page_label': '5'}
# {'producer': 'GPL Ghostscript 9.05', 'creator': '', 'creationdate': '2015-01-18T06:20:31-08:00', 'moddate': '2015-01-18T06:20:31-08:00', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\A_New_Generation_of_the_IMAGIC_Image_Pro.pdf', 'total_pages': 8, 'page': 5, 'page_label': '6'}
# {'producer': 'GPL Ghostscript 9.05', 'creator': '', 'creationdate': '2015-01-18T06:20:31-08:00', 'moddate': '2015-01-18T06:20:31-08:00', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\A_New_Generation_of_the_IMAGIC_Image_Pro.pdf', 'total_pages': 8, 'page': 6, 'page_label': '7'}
# {'producer': 'GPL Ghostscript 9.05', 'creator': '', 'creationdate': '2015-01-18T06:20:31-08:00', 'moddate': '2015-01-18T06:20:31-08:00', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\A_New_Generation_of_the_IMAGIC_Image_Pro.pdf', 'total_pages': 8, 'page': 7, 'page_label': '8'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 0, 'page_label': '1'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 1, 'page_label': '2'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 2, 'page_label': '3'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 3, 'page_label': '4'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 4, 'page_label': '5'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 5, 'page_label': '6'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 6, 'page_label': '7'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 7, 'page_label': '8'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 8, 'page_label': '9'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 9, 'page_label': '10'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 10, 'page_label': '11'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 11, 'page_label': '12'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 12, 'page_label': '13'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 13, 'page_label': '14'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 14, 'page_label': '15'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 15, 'page_label': '16'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 16, 'page_label': '17'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 17, 'page_label': '18'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 18, 'page_label': '19'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 19, 'page_label': '20'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 20, 'page_label': '21'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 21, 'page_label': '22'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 22, 'page_label': '23'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 23, 'page_label': '24'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 24, 'page_label': '25'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 25, 'page_label': '26'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 26, 'page_label': '27'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 27, 'page_label': '28'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 28, 'page_label': '29'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 29, 'page_label': '30'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 30, 'page_label': '31'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 31, 'page_label': '32'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 32, 'page_label': '33'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 33, 'page_label': '34'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 34, 'page_label': '35'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 35, 'page_label': '36'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 36, 'page_label': '37'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 37, 'page_label': '38'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 38, 'page_label': '39'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 39, 'page_label': '40'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 40, 'page_label': '41'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 41, 'page_label': '42'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 42, 'page_label': '43'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 43, 'page_label': '44'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 44, 'page_label': '45'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 45, 'page_label': '46'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 46, 'page_label': '47'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 47, 'page_label': '48'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 48, 'page_label': '49'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 49, 'page_label': '50'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 50, 'page_label': '51'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 51, 'page_label': '52'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 52, 'page_label': '53'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 53, 'page_label': '54'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 54, 'page_label': '55'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 55, 'page_label': '56'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 56, 'page_label': '57'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 57, 'page_label': '58'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 58, 'page_label': '59'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 59, 'page_label': '60'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 60, 'page_label': '61'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 61, 'page_label': '62'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 62, 'page_label': '63'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 63, 'page_label': '64'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 64, 'page_label': '65'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 65, 'page_label': '66'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 66, 'page_label': '67'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 67, 'page_label': '68'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 68, 'page_label': '69'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 69, 'page_label': '70'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 70, 'page_label': '71'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 71, 'page_label': '72'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 72, 'page_label': '73'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 73, 'page_label': '74'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 74, 'page_label': '75'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 75, 'page_label': '76'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 76, 'page_label': '77'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 77, 'page_label': '78'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 78, 'page_label': '79'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 79, 'page_label': '80'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 80, 'page_label': '81'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 81, 'page_label': '82'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 82, 'page_label': '83'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 83, 'page_label': '84'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 84, 'page_label': '85'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 85, 'page_label': '86'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 86, 'page_label': '87'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 87, 'page_label': '88'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 88, 'page_label': '89'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 89, 'page_label': '90'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 90, 'page_label': '91'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 91, 'page_label': '92'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 92, 'page_label': '93'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 93, 'page_label': '94'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 94, 'page_label': '95'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 95, 'page_label': '96'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 96, 'page_label': '97'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 97, 'page_label': '98'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 98, 'page_label': '99'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 99, 'page_label': '100'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 100, 'page_label': '101'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 101, 'page_label': '102'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 102, 'page_label': '103'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 103, 'page_label': '104'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 104, 'page_label': '105'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 105, 'page_label': '106'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 106, 'page_label': '107'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 107, 'page_label': '108'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 108, 'page_label': '109'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 109, 'page_label': '110'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 110, 'page_label': '111'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 111, 'page_label': '112'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 112, 'page_label': '113'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 113, 'page_label': '114'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 114, 'page_label': '115'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 115, 'page_label': '116'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 116, 'page_label': '117'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 117, 'page_label': '118'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 118, 'page_label': '119'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 119, 'page_label': '120'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 120, 'page_label': '121'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 121, 'page_label': '122'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 122, 'page_label': '123'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 123, 'page_label': '124'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 124, 'page_label': '125'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 125, 'page_label': '126'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 126, 'page_label': '127'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 127, 'page_label': '128'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 128, 'page_label': '129'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 129, 'page_label': '130'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 130, 'page_label': '131'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 131, 'page_label': '132'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 132, 'page_label': '133'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 133, 'page_label': '134'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 134, 'page_label': '135'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 135, 'page_label': '136'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 136, 'page_label': '137'}
# ...
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 403, 'page_label': '404'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 404, 'page_label': '405'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 405, 'page_label': '406'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 406, 'page_label': '407'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 407, 'page_label': '408'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 408, 'page_label': '409'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 409, 'page_label': '410'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 410, 'page_label': '411'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 411, 'page_label': '412'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 412, 'page_label': '413'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 413, 'page_label': '414'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 414, 'page_label': '415'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 415, 'page_label': '416'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 416, 'page_label': '417'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 417, 'page_label': '418'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 418, 'page_label': '419'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 419, 'page_label': '420'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 420, 'page_label': '421'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 421, 'page_label': '422'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 422, 'page_label': '423'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 423, 'page_label': '424'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 424, 'page_label': '425'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 425, 'page_label': '426'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 426, 'page_label': '427'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 427, 'page_label': '428'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 428, 'page_label': '429'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 429, 'page_label': '430'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 430, 'page_label': '431'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 431, 'page_label': '432'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 432, 'page_label': '433'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 433, 'page_label': '434'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 434, 'page_label': '435'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 435, 'page_label': '436'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 436, 'page_label': '437'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 437, 'page_label': '438'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 438, 'page_label': '439'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 439, 'page_label': '440'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 440, 'page_label': '441'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 441, 'page_label': '442'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 442, 'page_label': '443'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 443, 'page_label': '444'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 444, 'page_label': '445'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 445, 'page_label': '446'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 446, 'page_label': '447'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 447, 'page_label': '448'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 448, 'page_label': '449'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 449, 'page_label': '450'}
# {'producer': 'GPL Ghostscript 9.10', 'creator': '', 'creationdate': '2017-04-29T07:52:52-07:00', 'moddate': '2017-04-29T07:52:52-07:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf', 'total_pages': 451, 'page': 450, 'page_label': '451'}

# %%
host = os.getenv("PINECONE_HOST")
index = pc.Index(host= host)
vectors = []

for i, embedding in enumerate(embeddings):
    vectors.append({
        "id": f"chunk-{i}",
        "values": embedding.tolist(),
        "metadata": {
            "text": chunks[i].page_content,
            "source": chunks[i].metadata.get("source"),
            "page": chunks[i].metadata.get("page")
        }
    })

# %%
def batch_upsert(index, vectors, namespace, batch_size=500):
    for i in range(0, len(vectors), batch_size):
        batch = vectors[i:i + batch_size]
        index.upsert(vectors=batch, namespace=namespace)

# %%
batch_upsert(
    index=index,
    vectors=vectors,
    namespace="rag-docs",
    batch_size=500   # safe value
)

# %%
# cosine similarity search
def retrieve_query(query,k=3):
    model = SentenceTransformer('sentence-transformers/all-MiniLM-L12-v2')
    query_embedding = model.encode(query).tolist()
    matching_result = index.query(
        vector=query_embedding,
        top_k=k,
        namespace="rag-docs",
        include_metadata=True
    )
    return matching_result

# %%
answer = retrieve_query("what is Discrete Wavelet Transformation")
print(answer.matches)
# Out:
# [{'id': 'chunk-1141',
#  'metadata': {'page': 399.0,
#               'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf',
#               'text': 'discrete wavelet transform (DWT), (2) quantization, and '
#                       '(3) entropy encod- \n'
#                       'ing. After preprocessing, each component is '
#                       'independently analyzed by a \n'
#                       "suitable discrete wavelet transform (DW'T). The DWT "
#                       'essentially decomposes \n'
#                       'each component into a number of subbands in different '
#                       'resolution levels. Each \n'
#                       'www.thietbiysinh.com.vn'},
#  'score': 0.70496756,
#  'sparse_values': {'indices': [], 'values': []},
#  'values': []}, {'id': 'chunk-309',
#  'metadata': {'page': 105.0,
#               'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf',
#               'text': 'WAVELET TRANSFORMS 83 \n'
#                       'and hence for dyadic decomposition, the wavelet '
#                       'coefficients can be derived \n'
#                       'accordingly as \n'
#                       '(5.11) \n'
#                       'This allows us to reconstruct the signal f(t) in from '
#                       'the discrete wavelet \n'
#                       'coefficients as \n'
#                       'cam \n'
#                       '(5.12) \n'
#                       'm=-m n=-m \n'
#                       'The transform shown in Eq. 5.10 is called the wavelet '
#                       'series, which is analo- \n'
#                       'gous to the Fourier series because the input function f '
#                       '(t) is still a continuous \n'
#                       'function whereas the transform coefficients are '
#                       'discrete. This is often called \n'
#                       'the discrete time wavelet transform (DTWT). For digital '
#                       'signal or image pro- \n'
#                       'cessing applications executed by a digital computer, '
#                       'the input signal f(t) \n'
#                       'needs to be discrete in nature because of the digital '
#                       'sampling of the original \n'
#                       'data, which is represented by a finite number of bits. '
#                       'When the input function \n'
#                       'f(t) as well as the wavelet parameters a and b are '
#                       'represented in discrete form, \n'
#                       'the transformation is commonly referred to as the '
#                       'discrete wavelet transform \n'
#                       '(DWT) of signal f (t) [6, 71.'},
#  'score': 0.6873494,
#  'sparse_values': {'indices': [], 'values': []},
#  'values': []}, {'id': 'chunk-310',
#  'metadata': {'page': 105.0,
#               'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf',
#               'text': 'f(t) as well as the wavelet parameters a and b are '
#                       'represented in discrete form, \n'
#                       'the transformation is commonly referred to as the '
#                       'discrete wavelet transform \n'
#                       '(DWT) of signal f (t) [6, 71. \n'
#                       'The discrete wavelet transform (DWT) became a very '
#                       'versatile signal pro- \n'
#                       'cessing tool after Mallat [6] proposed the '
#                       'multiresolution representation of sig- \n'
#                       'nals based on wavelet decomposition. The advantage of '
#                       'the DWT over Fourier \n'
#                       'transformation is that it performs multiresolution '
#                       'analysis of signals with lo- \n'
#                       'calization both in time and frequency, popularly known '
#                       'as time-frequency \n'
#                       'localization. As a result, the DWT decomposes a digital '
#                       'signal into different \n'
#                       'subbands so that the lower-frequency subbands have '
#                       'finer frequency resolution \n'
#                       'and coarser time resolution compared to the '
#                       'higher-frequency subbands. The \n'
#                       'DWT is being increasingly used for image compression '
#                       'due to the fact that \n'
#                       'the DWT supports features like progressive image '
#                       'transmission (by quality, by'},
#  'score': 0.6867447,
#  'sparse_values': {'indices': [], 'values': []},
#  'values': []}]

# %%
print(answer.matches[0].id)
print(answer.matches[0].metadata)
print(answer.matches[0].metadata['page'])
print(answer.matches[0].metadata['source'])
print(answer.matches[0].metadata['text'])
print(answer.matches[0].score)
# Out:
# chunk-1141
# {'page': 399.0, 'text': "discrete wavelet transform (DWT), (2) quantization, and (3) entropy encod- \ning. After preprocessing, each component is independently analyzed by a \nsuitable discrete wavelet transform (DW'T). The DWT essentially decomposes \neach component into a number of subbands in different resolution levels. Each \nwww.thietbiysinh.com.vn", 'source': '..\\data\\research_data\\Image_processing_principles_and_applicat.pdf'}
# 399.0
# ..\data\research_data\Image_processing_principles_and_applicat.pdf
# discrete wavelet transform (DWT), (2) quantization, and (3) entropy encod-
# ing. After preprocessing, each component is independently analyzed by a
# suitable discrete wavelet transform (DW'T). The DWT essentially decomposes
# each component into a number of subbands in different resolution levels. Each
# www.thietbiysinh.com.vn
# 0.70496756

# %%
# context = "\n\n".join([doc.metadata['text'] for doc in answer.matches])
# print(context)
context = []
for doc in answer.matches:
    context.append(doc.metadata['text'])
print(context)
# Out:
# ['17.3 PARTS OF THE JPEG2000 STANDARD \nAs of writing this book, the standard has 11 parts (because Part 7 has been \nabandoned) with each part adding new features to the core standard in Part \n1. The 11 parts and their features are as follows: \n0 Part 1-Core Coding System [l, 141 specifies the basic feature set and \ncode-stream syntax for JPEG2000. \n0 Part 2-Extensions [15] to Part 1. This part adds a lot more features \nto the core coding system. \n0 Part 3-Motion JPEG2000 [16] specifies a file format (MJ2) that con- \ntains an image sequence encoded with the JPEG2000 core coding algo- \nrithm for motion video. \n0 Part 4-Conformance Testing [17] is now published as an International \nStandard (ISO/IEC 15444-4:2002). It specifies compliance-testing pro-', "372 JPEG2000 STANDARD FOR IMAGE COMPRESSION \nFig 17.1 Example of capabilities of' JPEG2000 technology.", "372 JPEG2000 STANDARD FOR IMAGE COMPRESSION \nFig 17.1 Example of capabilities of' JPEG2000 technology."]

# %%
# LLM integration: llama-3.1-8b-instant
from langchain_groq import ChatGroq

### Initialize the Groq LLM (set your GROQ_API_KEY in environment)
groq_api_key = os.getenv("GROQ_API_KEY")

llm=ChatGroq(groq_api_key=groq_api_key,model_name="llama-3.1-8b-instant",temperature=0.1,max_tokens=1024)

## 2. Simple RAG function: retrieve context + generate response
def rag_simple(query,llm,top_k=3):
    ## retriever the context
    results=answer.matches[:top_k]
    context = []
    for doc in answer.matches:
        context.append(doc.metadata['text'])
    if not context:
        return "No relevant context found to answer the question."
    
    ## generate the answwer using GROQ LLM
    prompt=f"""Use the following context to answer the question concisely.
        Context:
        {context}

        Question: {query}

        Answer:"""
    
    response=llm.invoke([prompt.format(context=context,query=query)])
    return response.content

# %%
answer = rag_simple("Discrete Wavelet Transformation", llm, top_k=3)
print(answer)
# Out:
# The Discrete Wavelet Transform (DWT) is a signal processing tool that decomposes a digital signal into different subbands with varying frequency and time resolutions. It is commonly used for image compression and supports features like progressive image transmission.
